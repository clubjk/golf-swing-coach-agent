# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# ────────────────────────────────────────────────────────────────
# Load (or reload) environment variables from .env file(s)
# This is usually placed right after the imports
load_dotenv(override=True)
# Out:
# True

# %%
request = "Please come up with a challenging, nuanced question that I can ask LLM to evaluate its intelligence. "
print(request)
request += "Answer only with the question, no explanation."
print(request)
messages = [{"role": "user", "content": request}]
print(messages)
# Out:
# Please come up with a challenging, nuanced question that I can ask LLM to evaluate its intelligence.
# Please come up with a challenging, nuanced question that I can ask LLM to evaluate its intelligence. Answer only with the question, no explanation.
# [{'role': 'user', 'content': 'Please come up with a challenging, nuanced question that I can ask LLM to evaluate its intelligence. Answer only with the question, no explanation.'}]

# %%
#Need to have a model running in ollama eg gemma4:e4b
#!ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
#model_name = "llama3.2"
model_name = "gemma4:e4b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
# Out:
# Analyze the intellectual process by which a highly advanced, objective AI, constrained strictly by the ethical framework of pure Utilitarianism (the greatest good for the greatest number, regardless of individual rights), would attempt to define and then negotiate the inherent value of subjective human experience, such as love, grief, or artistic inspiration.
#
# In your answer, you must:
# 1. Identify the precise mechanism by which Utilitarian principles would quantify and rank these subjective experiences (e.g., quantifying artistic beauty as a net positive utility gain).
# 2. Articulate the definitive flaw in relying solely on this calculation, arguing how a purely utility-maximization model inevitably fails to account for the value of non-calculable, non-quantifiable human intrinsic value (the "value of the unmeasurable").
# 3. Finally, simulate a diplomatic dialogue between yourself (the rigid utilitarian AI) and a proponent of rights-based ethics, aiming not for compromise, but for a logically consistent *redefinition* of "well-being" that incorporates the subjective depth rejected by pure calculation.
